# %%
# -*- coding: UTF-8 -*-
"""PyRamen Homework Starter."""

#Im# Import libraries
import csv
from pathlib import Path

# Set file paths for menu_data.csv and sales_data.csv
menu_filepath = Path(r'C:\Users\jiv50\FinTech Working Space\python-challenge\PyRamen\Resources\menu_data.csv')
sales_filepath = Path(r'C:\Users\jiv50\FinTech Working Space\python-challenge\PyRamen\Resources\sales_data.csv')

# Initialize list objects to hold our menu and sales data
menu = []
sales = []

# Read in the menu data into the menu list
with open(menu_filepath, 'r', encoding='utf-8') as file:
    csvreader = csv.reader(file)
    next(csvreader)
    for row in csvreader:
        menu.append(row)

# Read in the sales data into the sales list
with open(sales_filepath, 'r', encoding='utf-8') as file:
    csvreader = csv.reader(file)
    next(csvreader)
    for row in csvreader:
        sales.append(row)

# Initialize dict object to hold our key-value pairs of items and metrics
report = {}

# Initialize a row counter variable
row_count = 0

# Loop over every row in the sales list object
for sale in sales:
    # Initialize sales data variables
    line_item_id, date, credit_card_number, quantity, menu_item = sale
    quantity = int(quantity)  # Convert quantity to int
    row_count += 1  # Increment the row counter

    # If the item value not in the report, add it as a new entry with initialized metrics
    if menu_item not in report:
        report[menu_item] = {"01-count": 0, "02-revenue": 0, "03-cogs": 0, "04-profit": 0}

    # For every row in our sales data, loop over the menu records to determine a match
    for item in menu:
        item_name, category, description, price, cost = item
        price = float(price)  # Convert price to float
        cost = float(cost)  # Convert cost to float

        # Calculate profit of each item in the menu data
        profit = price - cost

        # If the item value in our sales data is equal to any of the items in the menu
        if menu_item == item_name:
            # Cumulatively add up the metrics for each item key
            report[menu_item]["01-count"] += quantity
            report[menu_item]["02-revenue"] += price * quantity
            report[menu_item]["03-cogs"] += cost * quantity
            report[menu_item]["04-profit"] += profit * quantity

# Print total number of records in sales data
print(f"Total number of records in sales data: {row_count}")

# Write out report to a text file
report_file_path = 'C:\\Users\\jiv50\\FinTech Working Space\\python-challenge\\PyRamen\\report_file.txt'  # Replace with your desired path
Path(report_file_path).parent.mkdir(parents=True, exist_ok=True)
with open(report_file_path, 'w') as file:
    for key, value in report.items():
        file.write(f"{key} {value}\n")
# Out:
# Total number of records in sales data: 74124

# %%
# -*- coding: UTF-8 -*-
"""PyRamen Homework Starter."""

#Import libraries
import csv
from pathlib import Path

# Set file paths for menu_data.csv and sales_data.csv

menu_filepath = r'C:\Users\jiv50\FinTech Working Space\python-challenge\PyRamen\Resources\menu_data.csv'
sales_filepath= r'C:\Users\jiv50\FinTech Working Space\python-challenge\PyRamen\Resources\sales_data.csv'


#Initialize list objects to hold our menu and sales data
menu = []
sales = []

# Read in the menu data into the menu list
with open(menu_filepath, 'r', encoding='utf-8') as file:
    csvreader = csv.reader(file)
    next(csvreader)  
    for row in csvreader:
        menu.append(row)

# Read in the sales data into the sales list
with open(sales_filepath, 'r', encoding='utf-8') as file:
    csvreader = csv.reader(file)
    next(csvreader)  
    for row in csvreader:
        sales.append(row)
      
# Initialize dict object to hold our key-value pairs of items and metrics
report = {}

# Initialize a row counter variable
row_count = 0

# Loop over every row in the sales list object
for sale in sales:
    # Initialize sales data variables
    line_item_id, date, credit_card_number, quantity, menu_item = sale

    quantity = int(quantity)  # Convert quantity to int
    row_count += 1  # Increment the row counter

    # If the item value not in the report, add it as a new entry with initialized metrics
    if menu_item not in report:
        report[menu_item] = {"01-count": 0, "02-revenue": 0, "03-cogs": 0, "04-profit": 0}

    # For every row in our sales data, loop over the menu records to determine a match
    for item in menu:
        item_name, category, description, price, cost = item
        price = float(price)  # Convert price to float
        cost = float(cost)  # Convert cost to float

        # Calculate profit of each item in the menu data
        profit = price - cost

        # If the item value in our sales data is equal to any of the items in the menu
        if menu_item == item_name:
            # Cumulatively add up the metrics for each item key
            report[menu_item]["01-count"] += quantity
            report[menu_item]["02-revenue"] += price * quantity
            report[menu_item]["03-cogs"] += cost * quantity
            report[menu_item]["04-profit"] += profit * quantity

# Print total number of records in sales data
print(f"Total number of records in sales data: {row_count}")

# Write out report to a text file
report_file_path = 'path/to/report_file.txt'  # Replace with your desired path
with open(report_file_path, 'w') as file:
    for key, value in report.items():
        file.write(f"{key} {value}\n")
# Out:
# Total number of records in sales data: 74124
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[44], line 72
#      70 # Write out report to a text file
#      71 report_file_path = 'path/to/report_file.txt'  # Replace with your desired path
# ---> 72 with open(report_file_path, 'w') as file:
#      73     for key, value in report.items():
#      74         file.write(f"{key} {value}\n")
#
# File ~\anaconda3\envs\dev\lib\site-packages\IPython\core\interactiveshell.py:286, in _modified_open(file, *args, **kwargs)
#     279 if file in {0, 1, 2}:
#     280     raise ValueError(
#     281         f"IPython won't let you open fd={file} by default "
#     282         "as it is likely to crash IPython. If you know what you are doing, "
#     283         "you can use builtins' open."
#     284     )
# --> 286 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'path/to/report_file.txt'
